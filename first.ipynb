# %% [markdown]
# MY first program

# %%
print("prateeksha ")
# Out:
# prateeksha

# %% [markdown]
# *My first program *

# %% [markdown]
# ***Variable decleration***
#
# rule 1: shd alwayys start with alphabet or _
#
# rule 2: should start with number
#
# rule 3:varilbe are case sensitive

# %%
a=5
b=6
sum=a+b
print(sum)
print("sum")
# Out:
# 11
# sum
