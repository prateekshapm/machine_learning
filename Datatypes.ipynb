# %% [markdown]
# **1.Strings**

# %%
name="Prateeksha"
print(type(name))
# Out:
# <class 'str'>

# %%
num1=56
num2=56.6
num3=4j
num4=-66
print(type(num1))
print(type(num2))
print(type(num3))
print(type(num4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'int'>

# %% [markdown]
# **Sequence Data Types**
#
# 1.List
# 2.Tuples
# 3.Range

# %% [markdown]
# Characteristics of list:
#
# 1.Ordered
#
# 2.Mutatiated
#
# 3.Allow repeating

# %%
lis=['122','prateeksha','12.45']
print(lis)
print(len(lis))
# Out:
# ['122', 'prateeksha', '12.45']
# 3

# %%
lis2=['12','m','0.45']
print(lis2)
print(len(lis2))
# Out:
# ['12', 'm', '0.45']
# 3

# %%
lis3=lis+lis2
print(lis3)
print(len(lis3))
# Out:
# ['122', 'prateeksha', '12.45', '12', 'm', '0.45']
# 6

# %%
lis3
# Out:
# ['122', 'prateeksha', '12.45', '12', 'm', '0.45']

# %%
lis2
# Out:
# ['12', 'm', '0.45']

# %%
lis3=lis+lis2
lis3
print(len(lis3))
# Out:
# 6

# %%
lis3.append('hii')
lis3
# Out:
# ['122', 'prateeksha', '12.45', '12', 'm', '0.45', 'hii']

# %%
lis2.clear()
lis2
# Out:
# []

# %%
lis4=['a','b','c','d']
lis4[0]
# Out:
# 'a'

# %%
lis3.sort()
lis3
# Out:
# ['0.45', '12', '12.45', '122', 'hii', 'm', 'prateeksha']

# %% [markdown]
# Tuples
#
# 1.ordered
#
# 2.changed
#
# 3.allows duplicated

# %%
tuple1=("hii","hello")
print(type(tuple1))
print(tuple1)
# Out:
# <class 'tuple'>
# ('hii', 'hello')
