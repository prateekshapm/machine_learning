# %% [markdown]
# <a href="https://colab.research.google.com/github/prateekshapm/machine_learning/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Linear Regression***
#
# Regression means to find the relationship that exists bwt dependent and independent variable.
#
# its a statical model that tells the realtionship bwt dependent and independent variable.
#
# in the form of y=mx+c where x is the independeng variable , and y is the dependent variable
#
# has 2 approches :
#
# 1.scikit learns model :
# a.givens answer acuratelly
#
# b.regularization present
#
# 2.statics mode :
# a.n number of variables are present as output
#
# b.no regularization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.array([1,5,6,8,9,13]).reshape(-1,1)
y=np.array([1,2,3,4,5,6])
plt.scatter(x,y)
plt.xlabel("independent variable")
plt.ylabel("dependent variable")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.linear_model import LinearRegression
slr=LinearRegression()
slr.fit(x,y)
# Out:
# LinearRegression()

# %%
pred=slr.predict(x)

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)

# %%
print("mse: ",mse)
print("INTERCEPT :" ,slr.intercept_)
print("slpoe :",slr.coef_)
plt.plot(x,pred,color='red',marker='*')
# Out:
# mse:  0.13414634146341461
# INTERCEPT : 0.3414634146341471
# slpoe : [0.45121951]
